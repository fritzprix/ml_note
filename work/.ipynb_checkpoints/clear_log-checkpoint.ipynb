# %%
import os
import sys

log_dir = "/home/tf_logs"

def rm_files(p):
    files = os.listdir(p)
    print(files)
    for c in files:
        abs_path = "{}/{}".format(p, c)
        try:
            os.remove(abs_path)
        except:
            try:
                os.rmdir(abs_path)
            except:
                rm_files(abs_path)
            
            

rm_files(log_dir)
# Out:
# ['rnn_stock_20210109_074624_10_50', 'rnn_stock_20210109_110555_20_50', 'rnn_stock_20210109_150732_10_40', 'rnn_sin_20210106_10_50.ckpt.index', 'rnn_stock_20210109_121201_20_50', 'rnn_stock_20210110_041032_10_40', 'rnn_mnist_20210103_143849_30_20.index', 'rnn_stock_20210103_151218_10_100', 'rnn_stock_20210106_143528_10_50', 'rnn_stock_20210103_150627_10_100', 'rnn_stock_20210109_123112_20_80', 'rnn_stock_20210109_084531_20_50', '.ipynb_checkpoints', 'rnn_stock_20210109_084427_20_50', 'rnn_stock_20210109_074610_10_50', 'rnn_stock_20210109_060140_10_10', 'rnn_stock_20210109_061655_20_10', 'rnn_stock_20210103_151349_10_100', 'rnn_stock_20210103_152236_10_100', 'rnn_stock_20210106_143545_10_50', 'rnn_stock_20210109_112947_20_50', 'rnn_stock_20210109_105411_20_50', 'rnn_stock_20210106_141408_10_50', 'rnn_stock_20210109_071505_10_50', 'rnn_mnist_20210103_062549_10_20', 'rnn_stock_20210109_060624_20_10', 'rnn_mnist_20210103_063401_30_20', 'rnn_stock_20210109_110535_20_50', 'rnn_stock_2021010
# ...
