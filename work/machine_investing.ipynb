# %% [markdown]
# ## Data source
#  - New article (world event)
#   - [NYT API](https://developer.nytimes.com/docs/articlesearch-product/1/overview)
#   - [GDELT (Event Database)](https://www.gdeltproject.org/data.html)
#
#  - 산업 / 경제 지표
#   - [통계청 API](https://sgis.kostat.go.kr/developer/html/openApi/api/intro.html)
#   - [KOSIS 공유서비스](http://kosis.kr/openapi/index/index.jsp)
#   - [한국은행 API](https://ecos.bok.or.kr/jsp/openapi/OpenApiController.jsp?t=main)
#  - 자산 가격 및 거래 정보
#   - investing.com
#     - [investing.com python API](https://pypi.org/project/investpy/)
#
#
# ## Python Tool
#   - [pyrtfolit](https://github.com/alvarobartt/pyrtfolio/)
#     - stock portifolio를 생성해 주는 python package -> 학습 시 cost function으로 활용 가능
#   - [trendet](https://github.com/alvarobartt/trendet/)
#     - stock price의 time series를 분석하여 up / down trend를 추출
#
#
# ## Machine Trading with Python
#  - [파이썬으로 배우는 알고리즘 트레이딩](https://wikidocs.net/6664)
